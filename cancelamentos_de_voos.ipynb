# %% [markdown]
# <a href="https://colab.research.google.com/github/JessePMelo/FlightOnTime-Previs-o-de-Atrasos-de-Voos/blob/main/cancelamentos_de_voos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bibliotecas usadas

# %%
import pandas as pd

# %% [markdown]
# Montando drive para subir os arquivos !

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Abrindo arquivos

# %%
import pandas as pd

path_anac = "/content/drive/MyDrive/Datasets Hackaton/Voos Regulares Ativos - Anac/VRA_20211.csv"

df_anac = pd.read_csv(
    path_anac,
    sep=';',
    encoding='utf8',
    header=1
)

df_anac.head()
# Out:
#   ICAO Empresa Aérea Número Voo Código Autorização (DI) Código Tipo Linha  \
# 0                TAM       3447                       0                 N
# 1                TAM       3447                       0                 N
# 2                TAM       3447                       0                 N
# 3                TAM       3447                       0                 N
# 4                TAM       3447                       0                 N
#
#   ICAO Aeródromo Origem ICAO Aeródromo Destino     Partida Prevista  \
# 0                  SBGR                   SBFI  2021-01-09 20:25:00
# 1                  SBGR                   SBFI  2021-01-10 20:25:00
# 2                  SBGR                   SBFI  2021-01-11 20:25:00
# 3                  SBGR                   SBFI  2021-01-12 20:25:00
# 4                  SBGR                   SBFI  2021-01-13 20:25:00
#
#           Partida Real     Chegada Prevista         Chegada Real Situação Voo  \
# ...

# %%
df_anac.shape
df_anac.columns
# Out:
# Index(['ICAO Empresa Aérea', 'Número Voo', 'Código Autorização (DI)',
#        'Código Tipo Linha', 'ICAO Aeródromo Origem', 'ICAO Aeródromo Destino',
#        'Partida Prevista', 'Partida Real', 'Chegada Prevista', 'Chegada Real',
#        'Situação Voo', 'Código Justificativa'],
#       dtype='object')

# %% [markdown]
# Deixando só as colunas essenciais

# %%
df_colunas_essenciais = df_anac[[
      "ICAO Empresa Aérea",
      "ICAO Aeródromo Origem",
      "ICAO Aeródromo Destino",
      "Partida Prevista",
      "Partida Real",
      "Situação Voo"
]]

# %% [markdown]
# Deixando somente os voos realizados

# %%
df_voos_realizados = df_colunas_essenciais[df_colunas_essenciais["Situação Voo"] == "REALIZADO"]

# %% [markdown]
# Conferindo

# %%
df_voos_realizados.shape
df_voos_realizados.head()
# Out:
#   ICAO Empresa Aérea ICAO Aeródromo Origem ICAO Aeródromo Destino  \
# 0                TAM                  SBGR                   SBFI
# 1                TAM                  SBGR                   SBFI
# 2                TAM                  SBGR                   SBFI
# 3                TAM                  SBGR                   SBFI
# 4                TAM                  SBGR                   SBFI
#
#       Partida Prevista         Partida Real Situação Voo
# 0  2021-01-09 20:25:00  2021-01-09 20:21:00    REALIZADO
# 1  2021-01-10 20:25:00  2021-01-10 20:24:00    REALIZADO
# 2  2021-01-11 20:25:00  2021-01-11 20:27:00    REALIZADO
# 3  2021-01-12 20:25:00  2021-01-12 20:24:00    REALIZADO
# 4  2021-01-13 20:25:00  2021-01-13 20:16:00    REALIZADO
